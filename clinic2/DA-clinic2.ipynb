# %% [markdown]
# # Clinics Group 30
#
# ## Emma Pinckers, Filip Sulich, Kamil Motyl
#
# ### i6356009, i6361564, i6262299
#
# **Use of genAI tools (e.g. chatGPT), websites (e.g. stackoverflow)**: *list websites where you found code (or other info) as well as include information on how you used genAI tools*

# %% [markdown]
# # Data Analysis
#
# # Clinic 2: I heard you are 👀 for a 🏠 in Utrecht
#
# By completing and delivering the clinic tasks you will know how to:
#
# - Work with real-world, messy datasets that require cleaning and preprocessing
# - Perform exploratory data analysis (EDA) to guide modeling decisions
# - Engineer new features, including spatial and polynomial features
# - Build reusable data processing pipelines in pandas
# - Train and evaluate linear and regularized models using scikit-learn
# - Use cross-validation to select model hyperparameters
# - Interpret models using feature importance techniques
# - Assess fairness by analyzing prediction errors across groups and locations
# - Communicate technical results clearly to both technical and non-technical audiences

# %% [markdown]
# **Important Dates.**
#
# - Clinic 2 release: Fri 06 Feb 2026
# - Clinic 2 due: Mon 23 Feb 2026 late night, wildcards available
#
# **Instructions for the deliverable: notebook and video**
#
# 1. Executed Notebook (.ipynb) (80 points)
#
# Your notebook should include the parts as here. All cells must be executed and outputs visible. Include answers to all questions and also explain your reasoning and describe any insights.
#
# ---
# 2. Short Video Presentation (up to 3 minutes) (20 points)
#
# Create a short video aimed at a **general (non-technical) audience** in which you explain:
#
# - What problem you were trying to solve
# - How you built your model (high level)
# - What features mattered most
# - Whether the model was fair across neighborhoods
# - One key insight or takeaway
#
# You do **not** need to include code in the video but you **should** include figures and plots. Focus on clarity, intuition and real-world implications.
#
# ---
# 🎯 Video Guidelines
#
# - Maximum length: **3 minutes**
# - Target audience: non-technical (e.g., city officials, homeowners, journalists)
# - You may use slides, screen recording or simple visuals
# - Avoid technical jargon as much as possible
# - Do **not** use AI-generated voices or AI video generators.
# - The presentation must use **your own voice**.
#
# ---
# ⚖️ Grading Considerations for the Video
#
# The video will be evaluated on:
#
# - Clarity of explanation
# - Correctness of interpretation
# - Engagement with fairness issues
# - Ability to communicate technical results simply
#
# ---
#
# 📅 Submission Format
#
# - Upload the executed notebook as `.ipynb`
# - Upload or link to your video (e.g., unlisted YouTube link, link to some storage space (e.g. google folder), other...)
#
# - **Honor code** applies to these tasks.
#   If you are not certain about an action, consult with Jerry.

# %% [markdown]
# **A philosophical note from Jerry on using Language Models (LMs)**
#
# You might have thought about it. Are LLMs going to replace data scientists?
#
# *Short answer*: No-one knows for sure. But, I have some hope.
#
#
# Here are my thoughts, for this clinic but in general as well. In many of our data analysis tasks we have 3 steps.
#
# + Step 1: Gather context and ask insightful questions. LLMs cannot deeply understand the nuanced desires, abilities, and personalities of complex organizations. At least for now 🙂
#
# + Step 2: Plan analyses that address your question(s). LLMs can provide advice as you weigh options. But, the choice of "best" analysis is often subjective. Experience matters. That's what people will pay you for in the future, not your ability to run Python.
#
# + Step 3: Run the analysis. With proper context and instructions, LLMs can help a lot here! But, you must be able to verify outputs. Don't do analysis by "vibes".

# %% [markdown]
# # 0. Introduction
#
# In this clinic, we will go through the iterative process of specifying, fitting, and refining a linear regression model using real-world housing data from Utrecht. Dataset is inspired from this [paper](https://ictinstitute.nl/utrecht-housing-dataset-2025/), which you are welcome to read!
#
# In the first part of the assignment, we will guide you through exploratory data analysis (EDA), laying out the thought process that leads to key data cleaning, transformation, and modeling decisions. We will then specify and fit increasingly refined linear models, providing examples of the type of code and workflow expected in the open-response section.
#
# The second part of the assignment is purposefully left open-ended. You will be allowed to build a linear model of your choice (e.g., linear regression, Ridge, Lasso) to better predict housing values.
#
# After completing this clinic, you should feel comfortable with:
#
# 1. Working with a real-world dataset that requires cleaning and preprocessing
#
# 1. Performing exploratory data analysis to inform modeling decisions
#
# 1. Building linear and regularized models using `sklearn`
#
# 1. Creating feature engineering pipelines with `pandas`
#
# 1. Using cross-validation for model selection and evaluation
#
# 1. Interpreting residuals and error metrics
#
# 1. Reflecting on fairness implications in predictive models
#
# ## Score breakdown
#
# Question | Points
# --- | ---
# [Question 1](#q1) | 5
# [Question 2a](#q2a) | 2
# [Question 2b](#q2b) | 2
# [Question 3](#q3) | 2
# [Question 4](#q4) | 8
# [Question 5](#q5) | 35
# [Question 6](#q6) | 15
# [Question 7](#q7) | 15
# Total | 80
#
# This score will be added to the video score (20), scaled down to 1 and that will be your final clinic score.

# %%
#necessary imports (edit as you see fit)
import numpy as np

import pandas as pd
from pandas.api.types import CategoricalDtype

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import linear_model as lm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# Plot settings
plt.rcParams['figure.figsize'] = (12, 9)
plt.rcParams['font.size'] = 12

#to show big values in numbers and not in scientific format
import matplotlib.ticker as mtick
pd.options.display.float_format = '{:,.2f}'.format
plt.rcParams['axes.formatter.useoffset'] = False
plt.rcParams['axes.formatter.use_locale'] = False

# %% [markdown]
# ## 0.1 The Data
#
# The dataset consists of several hundred residential properties in Utrecht and includes structural, spatial, and energy-related features.
#
# Some of the key variables include, for more details refer to the `codebook.txt`:
#
# ```
# retailvalue – estimated market value of the property (our main prediction target)
#
# taxvalue – assessed value used for taxation purposes
#
# house-area, lot-area, garden-size – size-related features
#
# bathrooms, buildyear – structural characteristics
#
# energy-eff – energy efficiency indicator
#
# monument – whether the property is a protected historical building
#
# zipcode, x-coor, y-coor – location information
# ```
#
# Together, these variables describe both the physical properties of homes and aspects related to sustainability and urban geography.
#
# Dataset is not split to training/test but we will use one common seed (to rule all splits).
#
# ### 0.1.1 Housing Valuation and Fairness
#
# 🌍 In many countries, including the Netherlands, property values are used to determine: property taxes, mortgage conditions, insurance costs.
#
# 💰 These values are often estimated using statistical or machine learning models that take into account characteristics such as size, location, and building quality.
#
# 🎯 While predictive accuracy is important, valuation models can also have distributional consequences. Systematic overvaluation or undervaluation of homes in certain areas or categories (e.g., energy-efficient homes, historic buildings, or specific neighborhoods) can lead to: higher tax burdens for some residents, unfair advantages for others.
#
# 🧪 In this clinic, we will not only aim to build accurate predictive models, but also examine who benefits and who may be harmed by modeling errors.
#
# 🏠📊 By analyzing residuals and group-wise error patterns (e.g., by zipcode, energy efficiency or monument status), we will reflect on how fairness can be understood in the context of housing valuation. That will also serve as a good basis for the guest lecture we are going to have on March 9th.

# %% [markdown]
# ### 📥 Load the dataset

# %%
data = pd.read_csv("utrechthousing.csv")

# %% [markdown]
# ### ✂️ Create train/test split
#
# Since the dataset is not pre-divided into training and test sets, we create our own split. The training set will be used to fit and tune our models, while the test set will be held out to evaluate performance on unseen data. To ensure reproducibility across different runs of the notebook, we fix the random seed before splitting.

# %%
# For reproducibility (so everyone gets the same split) ###DO NOT CHANGE
np.random.seed(1983)

# Split: 80% train, 20% test
training_data, testing_data = train_test_split(
    data, 
    test_size=0.2, 
    random_state=1983
)

# %% [markdown]
# As a good sanity check, we should at least verify that the data shape matches the description.

# %%
# Check sizes
#1516,16
print("Train shape:", training_data.shape)
#379,16
print("Test shape:", testing_data.shape)

# They should sum to full dataset
assert training_data.shape[0] + testing_data.shape[0] == data.shape[0]

# Same columns in both
assert set(training_data.columns) == set(testing_data.columns)
# Out:
# Train shape: (1516, 16)
# Test shape: (379, 16)

# %% [markdown]
# The next order of business is getting a feel for the variables in our data.  The Ames data set contains information that typical homebuyers would want to know.  A more detailed description of each variable is included in `codebook.txt`.  **You should take some time to familiarize yourself with the codebook before moving forward.** If you find any issues or inconsistencies in the codebook, please report them to us!

# %%
training_data.columns.values
# Out:
# array(['id', 'zipcode', 'lot-len', 'lot-width', 'lot-area', 'house-area',
#        'garden-size', 'balcony', 'x-coor', 'y-coor', 'buildyear',
#        'bathrooms', 'taxvalue', 'retailvalue', 'energy-eff', 'monument'],
#       dtype=object)

# %% [markdown]
# # 1. Guided Modeling
#
# In the first part of the assignment, we will take you step-by-step through one cycle of the modeling process.  Along the way, we will provide commentary to give you a sense of the thought process that goes into building a model. We give examples on most of the common cases we have explored (EDA, missing values, feature engineering etc.), but feel free to extend this analyses for your final model.
#
# ## 1.1 EDA
# Naturally, the first thing we want to do is get a feel for our data.  In this section, we will make a series of exploratory visualizations.  The plots we ask you to reproduce here are far from exhaustive. **When you build your own model in the second part of this assignment, you will want to delve deeper into the data.**
#
# Note that we will perform EDA on the **training data** so that information from the test data does not influence our modeling decisions.
#
# ### 1.1.1 Retail-value
# We begin by examining a [raincloud plot](https://www.kaggle.com/code/carlmcbrideellis/box-strip-violin-raincloud-plot) (yet another name for a combination of a KDE, a boxplot, and a boxplot all-in-one) of our target variable `SalePrice`.  At the same time, we also take a look at some descriptive statistics of this variable.

# %%
fig, axs = plt.subplots(nrows=2)

sns.histplot(
    training_data["retailvalue"],
    kde=True,
    ax=axs[0]
)

sns.stripplot(
    training_data["retailvalue"],
    orient="h",
    jitter=0.4,
    size=3,
    ax=axs[1],
    alpha=0.3
)

sns.boxplot(
    training_data["retailvalue"],
    orient="h",
    width=0.4,
    ax=axs[1],
    showfliers=False,
)

# Align axes
spacer = np.max(training_data["retailvalue"]) * 0.05
xmin = np.min(training_data["retailvalue"]) - spacer
xmax = np.max(training_data["retailvalue"]) + spacer
axs[0].set_xlim((xmin, xmax))
axs[1].set_xlim((xmin, xmax))

axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_visible(False)
axs[1].yaxis.set_visible(False)

plt.subplots_adjust(hspace=0)
axs[1].set_facecolor("white")
#remove scientific format
axs[1].xaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %%
#Summary statistics for price
training_data["retailvalue"].describe()
# Out:
# count       1,516.00
# mean      791,773.75
# std       211,424.32
# min       419,000.00
# 25%       632,750.00
# 50%       768,000.00
# 75%       911,500.00
# max     1,428,000.00
# Name: retailvalue, dtype: float64

# %%
print(f"Median: {training_data['retailvalue'].median()}")
print(f"Mean: {training_data['retailvalue'].mean()}")
# Out:
# Median: 768000.0
# Mean: 791773.746701847

# %% [markdown]
# To check your understanding of the graph and summary statistics above, answer the following `True` or `False` questions:
#
# 1. The distribution of `retailvalue` in the training set is left-skew. - False
# 1. The mean of `retailvalue` in the training set is greater than the median. - True
# 1. 75% of the houses in the training set sold for less than 911,250.00. euro - True
#
# If you have trouble answering the questions above, discuss them in class with each other and confirm with a TA

# %% [markdown]
# ### 1.1.2 Retail Value vs House Area
#
# Next, we examine `retailvalue` vs `house-area` (living area in m²).

# %%
g= sns.jointplot(
    x="house-area",
    y="retailvalue",
    data=training_data,
    kind="reg",
    ratio=4,
    space=0,
    scatter_kws={"s": 12, "alpha": 0.25},
    line_kws={"color": "black"}
)

g.ax_joint.xaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
g.ax_joint.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# We often expect a roughly linear relationship between size and value, but we should also look for unusual points (potential outliers). In this dataset, a small number of houses have house-area above 300 m². Let’s inspect them.

# %%
# q2house1 and q2house2 should be integers
q2house1 = training_data.loc[training_data["house-area"] > 300, "id"].iloc[0].item()
q2house2 = training_data.loc[training_data["house-area"] > 300, "id"].iloc[1].item()

q2house1, q2house2
# Out:
# (631929, 642836)

# %% [markdown]
# Below we write a function `remove_outliers` that removes outliers from a data set based off a threshold value of a variable. For example, `remove_outliers(training_data, 'house-area', upper=300)` should return a data frame with only observations that satisfy `house-area` less than or equal to 300.

# %%
def remove_outliers(data, variable, lower=-np.inf, upper=np.inf):
    """
    Input:
      data (data frame): the table to be filtered
      variable (string): the column with numerical outliers
      lower (numeric): observations with values lower than this will be removed
      upper (numeric): observations with values higher than this will be removed
    
    Output:
      a winsorized data frame with outliers removed
    """
    return data.loc[(data[variable] > lower) & (data[variable] < upper)]


training_data = remove_outliers(training_data, "house-area", upper=300)

# %%
#making sure the two observations were removed

assert training_data.shape[0] == 1514

# %% [markdown]
# ### 1.1.3 Zipcode vs Retail Value
#
# Next we explore this relationship. We have a small set of 4-digit zipcodes. Location is often one of the strongest predictors of housing value, so let’s inspect how values differ across zipcodes.

# %%
fig, axs = plt.subplots(nrows=2)

sns.boxplot(
    x="zipcode",
    y="retailvalue",
    data=training_data.sort_values("zipcode"),
    ax=axs[0]
)

sns.countplot(
    x="zipcode",
    data=training_data.sort_values("zipcode"),
    ax=axs[1]
)

axs[0].axhline(
    y=training_data["retailvalue"].median(),
    color="green",
    linestyle="dotted"
)

for patch in axs[1].patches:
    x = patch.get_bbox().get_points()[:, 0]
    y = patch.get_bbox().get_points()[1, 1]
    axs[1].annotate(f"{int(y)}", (x.mean(), y), ha="center", va="bottom")

axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.subplots_adjust(hspace=0.01)
plt.show()

# %% [markdown]
# What do you think? Are there differences or maybe outliers?
#
# While the dataset includes a zipcode variable, these administrative boundaries are relatively coarse and may not fully capture finer-grained spatial patterns in housing prices. Homes that are geographically close to each other can belong to different zipcodes, while homes far apart may share the same zipcode. As a result, relying solely on zipcode may obscure important local effects related to accessibility, amenities, and neighborhood characteristics.
#
# To better represent spatial structure in the data, we will create a new variable that groups houses into data-driven neighborhoods based directly on their geographic coordinates (`x-coor` and `y-coor`). Using a simple clustering technique, we partition the city into contiguous spatial regions that reflect natural groupings of properties. These spatial neighborhoods provide a more flexible and fine-grained representation of location than zipcode alone.
#
# After constructing these spatial neighborhoods, we will identify the most expensive ones (based on median housing value) and create a binary indicator variable, `in_rich_neighborhood`, which marks whether a house lies in one of these high-value areas.
#
# This additional feature allows our models to incorporate local spatial effects more effectively and provides a useful lens for later fairness analysis, where we will examine whether prediction errors systematically differ across regions of the city.

# %%
from sklearn.cluster import KMeans

def add_spatial_neighborhoods(data, k=8, random_state=1983):
    data = data.copy()
    
    coords = data[["x-coor", "y-coor"]]
    
    kmeans = KMeans(n_clusters=k, random_state=random_state)
    data["spatial_neighborhood"] = kmeans.fit_predict(coords)
    
    return data

# %%
training_data = add_spatial_neighborhoods(training_data, k=8)
training_data["spatial_neighborhood"].value_counts()
# Out:
# spatial_neighborhood
# 0    210
# 3    202
# 6    192
# 5    192
# 7    192
# 1    184
# 2    178
# 4    164
# Name: count, dtype: int64

# %%
sns.scatterplot(
    x="x-coor",
    y="y-coor",
    hue="spatial_neighborhood",
    data=training_data,
    palette="tab20"
)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Data-driven Spatial Neighborhoods")
plt.show()

# %% [markdown]
# So now let's replot the previous figure but with this variable.

# %%
fig, axs = plt.subplots(nrows=2)

sns.boxplot(
    x="spatial_neighborhood",
    y="retailvalue",
    data=training_data.sort_values("spatial_neighborhood"),
    ax=axs[0]
)

sns.countplot(
    x="spatial_neighborhood",
    data=training_data.sort_values("spatial_neighborhood"),
    ax=axs[1]
)

axs[0].axhline(
    y=training_data["retailvalue"].median(),
    color="green",
    linestyle="dotted"
)

for patch in axs[1].patches:
    x = patch.get_bbox().get_points()[:, 0]
    y = patch.get_bbox().get_points()[1, 1]
    axs[1].annotate(f"{int(y)}", (x.mean(), y), ha="center", va="bottom")

axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.subplots_adjust(hspace=0.01)
plt.show()

# %% [markdown]
# Okay, now we managed to have some more variation and seems that in some cases retail values differ by the location and the number of observations is not identical across zipcodes.
#
# Let's apply a simple binning trick and mark the top-3 locations by median retail value as “pricey neighborhoods”.

# %%
def find_pricey_neighborhoods(data, n=3, metric=np.median):
    """
    Returns a list of the top-n neighboorhoods by aggregated retailvalue (default: median).
    """
    tmp = data.groupby("spatial_neighborhood")["retailvalue"].agg(metric).sort_values(ascending=False)
    return tmp.head(n).index.tolist()

pricey_locs = find_pricey_neighborhoods(training_data, 3, np.median)
pricey_locs
# Out:
# /var/folders/nr/npwcl3b53m7d_lm5jnd6qqt40000gn/T/ipykernel_92734/1944340939.py:5: FutureWarning: The provided callable <function median at 0x116302f20> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   tmp = data.groupby("spatial_neighborhood")["retailvalue"].agg(metric).sort_values(ascending=False)
# [5, 7, 0]

# %% [markdown]
# And we can add such a categorization to the dataset

# %%
def add_in_pricey_neighborhood(data, locs):
    """
    Adds a binary column in_pricey_neighborhoods:
      1 if location is in the provided list, else 0
    """
    data = data.copy()
    data["in_pricey_neighborhoods"] = data["spatial_neighborhood"].isin(locs).astype(int)
    return data

training_data = add_in_pricey_neighborhood(training_data, pricey_locs)
assert training_data["in_pricey_neighborhoods"].isnull().sum() == 0

# %%
training_data.head()
# Out:
#           id  zipcode  lot-len  lot-width  lot-area  house-area  garden-size  \
# 818   473504     3500    15.10       8.50    128.40      191.25        26.40
# 423   292120     3800    16.10       8.60    138.50      116.10        35.30
# 296   233225     3525    11.20       6.50     72.80       87.75         7.80
# 1739  882688     3525    14.00      10.60    148.40      190.80        42.40
# 1126  603592     3500    19.70       6.60    130.00       89.10        50.80
#
#       balcony  x-coor  y-coor  buildyear  bathrooms  taxvalue  retailvalue  \
# 818         1    2509    5864       2003          1    868000       969000
# 423         2    2613    5511       1973          1    575000       721000
# 296         0    2119    5802       2001          1    409000       480000
# 1739        1    2400    5662       1982          2    882000      1068000
# 1126        1    2966    5856       2001          1    460000       479000
#
#       energy-eff  monument  spatial_neighborhood  in_pricey_neighborhoods
# 818            0         0                     6                        0
# 423            0         0                     5                        1
# 296            1         0                     2                        0
# 1739           1         1                     6                        0
# 1126           1         0                     0                        1

# %% [markdown]
# Bonus (curiosity): Which are these expensive neighboorhoods in Utrecht?
#
# Feel free to use (or adapt) this feature in your latter analysis.

# %% [markdown]
# ## 1.2 Missing Data
#
# Let's see if our data set has any missing values.
#
# 👉 You should observe that there are no missing values in this dataset.

# %%
missing_counts = training_data.isnull().sum().sort_values(ascending=False)

assert isinstance(missing_counts, pd.Series)
assert missing_counts.size == training_data.shape[1]
assert set(missing_counts.index.values) == set(training_data.columns.values)

missing_counts
# Out:
# id                         0
# zipcode                    0
# spatial_neighborhood       0
# monument                   0
# energy-eff                 0
# retailvalue                0
# taxvalue                   0
# bathrooms                  0
# buildyear                  0
# y-coor                     0
# x-coor                     0
# balcony                    0
# garden-size                0
# house-area                 0
# lot-area                   0
# lot-width                  0
# lot-len                    0
# in_pricey_neighborhoods    0
# dtype: int64

# %% [markdown]
# ## 1.3 Feature Engineering
#
# In this section we will create a new feature out of existing ones through a simple data transformation.  When you move on to create your own model, you may want to try out more complex transformations.
#
# ### 1.3.1 House age
#
# We’ll create a variable `house_age` based on `buildyear`. Since the dataset does not include a valuation year column, we’ll define age relative to a fixed reference year (2025 is fine for this dataset).

# %%
def add_house_age(data, reference_year=2025):
    data = data.copy()
    data["house_age"] = reference_year - data["buildyear"]
    return data

training_data = add_house_age(training_data)

# %%
# Check that no missing values were created
assert ~training_data["house_age"].isnull().any()

# %% [markdown]
# ### 1.3.2 Total Outdoor Space
#
# Outdoor space can matter a lot for price. We create:
#
# ```total_outdoor = lot-area + garden-size```

# %%
def add_total_outdoor(data):
    data = data.copy()
    data["total_outdoor"] = data["lot-area"] + data["garden-size"]
    return data

# %%
# Simple check
training_data = add_total_outdoor(training_data)
assert ~training_data["total_outdoor"].isnull().any()

# %% [markdown]
# #### Question 1 <a id="q1"></a>
#
# Propose and justify at least two new features derived from existing variables.
# Explain why they might improve predictive performance and how they could affect fairness.
#
# (at this point we don't care if we are going to use them or not, we just make some hypothesis)

# %%
#code for feature 1

# We want to capture the relationship between the size of the house and the size of the lot - we expect that a large house on a small lot is more expensive than a small house on a large lot.
def compute_house_to_lot_ratio(data):
    data = data.copy()
    data["house_to_lot_ratio"] = data["house-area"] / data["lot-area"]
    return data

training_data = compute_house_to_lot_ratio(training_data)
assert ~training_data["house_to_lot_ratio"].isnull().any()

# %% [markdown]
# justification for feature 1 (predictive+fairness)
#
# ### Predictive justification:
# It is a useful metric as if there is high house-to-lot ratio, it means that the area is densely built, possibly urban area or townhouse (not a lot of free space). If the ratio is low, it means there is more outdoor space, possibly suburban with gardens. This feature captures building density - how efficiently is the avaiable space used, which correlates with location and retail price.
# ### Fairness justification:
# Dense urban areas may have different demographics than suburban areas, influencing the price dynamics.

# %%
#code for feature 2
x_center = training_data["x-coor"].median()
y_center = training_data["y-coor"].median()
center_coords = (x_center, y_center) # we use the median of the coordinates as the center

def compute_distance_to_center(data, center_coords=center_coords):
    data = data.copy()
    dx = data["x-coor"] - center_coords[0]
    dy = data["y-coor"] - center_coords[1]
    data["distance_to_center"] = np.sqrt(dx**2 + dy**2) / 1000  #euclidean distance in kilometers
    return data

training_data = compute_distance_to_center(training_data)
assert ~training_data["distance_to_center"].isnull().any()

# %% [markdown]
# justification for feature 2 (predictive+fairness)
#
# ### Predictive justification:
# Proximity to city center is very often strongly correlated with property values (properties closer to the center are usually more expensive due to their accessibility to jobs and amenities). This feature would allow the model to capture location-based price differences.
# ### Fairness justification:
# By including this feature we make model predictions more transparent and consistent, as the model explicitly knows that houses closer to the city center are more valuable and it doesn't need to infer it indirectly (which could introduce some bias).

# %% [markdown]
# # 2. Modeling
#
# We’ve finally gotten to a point where we can specify a simple model. Since the Utrecht dataset is not pre-split into training and test files, we will create our own split. We will treat `utrechthousing.csv` as the complete dataset, use `train_test_split` to create `training_data` and `testing_data`, and then evaluate model performance on the test set.
#
# As before, we will keep our preprocessing in reusable functions so we can apply the exact same pipeline to both training and testing data.

# %%
# Load a fresh copy of the data
full_data = pd.read_csv("utrechthousing.csv")

# Reproducible split
training_data, testing_data = train_test_split(full_data, test_size=0.2, random_state=1983)

# Sanity checks
assert training_data.shape == (1516, 16) #note that we are re-loading the dataset here and we apply pre-processing again later
assert testing_data.shape == (379, 16)
assert set(training_data.columns) == set(testing_data.columns)

# %% [markdown]
# Below we copy the functions we used before (you can add yours of course or modify them). Actually, we expect that you adapt this part for the next part (Question 5) but feel free to already adapt it here aswell.

# %%
from sklearn.cluster import KMeans

def select_columns(data, *columns):
    return data.reindex(columns=columns)

def remove_outliers(data, variable, lower=-np.inf, upper=np.inf):
    return data.loc[(data[variable] > lower) & (data[variable] < upper)]

def add_house_age(data, reference_year=2025):
    data = data.copy()
    data["house_age"] = reference_year - data["buildyear"]
    return data

def add_total_outdoor(data):
    data = data.copy()
    data["total_outdoor"] = data["lot-area"] + data["garden-size"]
    return data

def fit_spatial_neighborhood_model(train_data, k=8, random_state=1337):
    coords = train_data[["x-coor", "y-coor"]]
    kmeans = KMeans(n_clusters=k, random_state=random_state, n_init=10)
    kmeans.fit(coords)
    return kmeans

def add_spatial_neighborhood(data, kmeans):
    data = data.copy()
    data["spatial_neighborhood"] = kmeans.predict(data[["x-coor", "y-coor"]])
    return data

def find_rich_spatial_neighborhoods(data, n=3, metric="median"):
    # Top-n clusters by median retailvalue
    tmp = (
        data.groupby("spatial_neighborhood")["retailvalue"]
        .agg(metric)
        .sort_values(ascending=False)
    )
    return tmp.head(n).index.tolist()

def add_in_rich_neighborhood(data, rich_clusters):
    data = data.copy()
    data["in_rich_neighborhood"] = data["spatial_neighborhood"].isin(rich_clusters).astype(int)
    return data

def add_location_terms(data):
    """
    Adds simple nonlinear location terms to allow spatial curvature with linear models.
    """
    data = data.copy()
    data["x2"] = data["x-coor"] ** 2
    data["y2"] = data["y-coor"] ** 2
    data["xy"] = data["x-coor"] * data["y-coor"]
    return data

def compute_house_to_lot_ratio(data):
    data = data.copy()
    data["house_to_lot_ratio"] = data["house-area"] / data["lot-area"]
    return data

def compute_distance_to_center(data):
    x_center = training_data["x-coor"].median()
    y_center = training_data["y-coor"].median()
    center_coords = (x_center, y_center) 
    data = data.copy()
    dx = data["x-coor"] - center_coords[0]
    dy = data["y-coor"] - center_coords[1]
    data["distance_to_center"] = np.sqrt(dx**2 + dy**2) / 1000  
    return data

# %% [markdown]
# ## 2.1 Reusable Pipeline
#
# Throughout this assignment, you should notice that your data flows through a single processing pipeline several times.  From a software engineering perspective, this should be sufficient motivation to abstract parts of our code into reusable functions/methods.  We will now encapsulate our entire pipeline into a single function `process_data_gm`.  gm is shorthand for "guided model".

# %%
## 2.1 Reusable Pipeline

def select_columns(data, *columns):
    return data.reindex(columns=columns)

def process_data_gm1(data):
    # -------------------
    # Clean Data
    # -------------------
    data = remove_outliers(data, "house-area", upper=300)

    # -------------------
    # Transform Data
    # -------------------
    data = add_house_age(data)
    data = add_total_outdoor(data)
    data = compute_house_to_lot_ratio(data)
    data = compute_distance_to_center(data)
    
        # -------------------

    # -------------------
    # Select modeling columns
    # -------------------
    data = select_columns(
        data,
        "retailvalue",
        "house-area",
        "bathrooms",
        "total_outdoor",
        "house_age",
        "balcony",
        "energy-eff",
        "monument",
    )

    # -------------------
    # Split predictors/target
    # -------------------
    X = data.drop(["retailvalue"], axis=1)
    y = data["retailvalue"]

    return X, y

# %% [markdown]
# An alternative way of writing the same code above explicitly allows us to think about our data flowing through a [pipeline](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pipe.html) where the output of one function is the input of the next.  Carefully thought out function names make the code self-documenting: you can just read off the intended high-level processing steps from top to bottom.
#
# You are not required to use this style of coding.  We just wanted to point out that it exists.

# %%
def process_data_gm1(data):

    data = (
        data
        # -------------------
        # Clean Data
        # -------------------
        .pipe(remove_outliers, "house-area", upper=300)

        # -------------------
        # Transform Data
        # -------------------
        .pipe(add_house_age)
        .pipe(add_total_outdoor)

        # -------------------
        # Select columns
        # -------------------
        .pipe(select_columns,
              "retailvalue",
              "house-area",
              "bathrooms",
              "total_outdoor",
              "house_age",
              "balcony",
              "energy-eff",
              "monument",
              )
    )

    X = data.drop(["retailvalue"], axis=1)
    y = data["retailvalue"]

    return X, y

# %% [markdown]
# ## 2.2 Fitting our first model
#
# We are finally going to fit a model (yay!). This part is slightly unceremonious since we did much of the heavy lifting in the previous sections. The model we will fit can be written as follows:
#
# $$
# \begin{align}
# \text{retailvalue} =\;& \theta_0
# + \theta_1 \times \text{HouseArea}
# + \theta_2 \times \text{Bathrooms} \\
# &+ \theta_3 \times \text{TotalOutdoor}
# + \theta_4 \times \text{HouseAge} \\
# &+ \theta_5 \times \text{EnergyEfficiency}
# + \theta_6 \times \text{Monument}
# + \theta_7 \times \text{Balcony}
# \end{align}
# $$
#
# where:
#
# - `HouseArea` corresponds to `house-area`
# - `Bathrooms` corresponds to `bathrooms`
# - `TotalOutdoor = lot-area + garden-size`
# - `HouseAge = current year − buildyear`
# - `EnergyEfficiency` corresponds to `energy-eff`
# - `Monument` is an indicator for historic buildings
# - `Balcony` is an indicator for balcony presence
#
#
# #### Question 2a <a name="q1a"></a>
# Remove the commenting and fill in the ellipses `...` below with `X_train`, `y_train`, `X_test`, or `y_test`.

# %%
# Pre-process our training and test data in exactly the same way
# Our functions make this very easy!
X_train, y_train = process_data_gm1(training_data)
X_test, y_test = process_data_gm1(testing_data)
guidedmodel1 = lm.LinearRegression(fit_intercept=True)

# Fill in the ... below with X_train, y_train, X_train, or X_test.
# Remember to uncomment
guidedmodel1.fit(X_train, y_train)
y_fitted = guidedmodel1.predict(X_train)
y_predicted = guidedmodel1.predict(X_test)

# %%
#print the result

print(y_fitted.mean())
print(y_predicted.mean())
# Out:
# 791103.6988110965
# 785924.2617644884

# %%
#if you fail these, might still be okay (but good to check your model, split etc.)
assert 790000 <= y_fitted.mean() <= 8000000
assert 780000 <= y_predicted.mean() <= 790000

# %%
# Mean prediction should not be wildly off from mean actual target in training/test
assert abs(y_fitted.mean() - y_train.mean()) / y_train.mean() < 0.25
assert abs(y_predicted.mean() - y_test.mean()) / y_test.mean() < 0.25

# %% [markdown]
# In this assignment, we will use Root-Mean-Square Error (RMSE) to measure the quality of our models.  As a reminder, this quantity is defined as:
#
# $$RMSE = \sqrt{\dfrac{\sum_{\text{houses in test set}}(\text{actual price of house} - \text{predicted price of house})^2}{\text{\# of houses in test set}}}$$
#
#
# #### Question 2b <a name="q1b"></a>
#
# Write a function `rmse` that calculates the RMSE of a model.  Again, make sure you are taking advantage of vectorized code.  This can be solved without any iteration.

# %%
def rmse(actual, predicted):
    """
    Calculates RMSE from actual and predicted values
    Input:
      actual (1D array-like): vector of actual values
      predicted (1D array-like): vector of predicted/fitted values
    Output:
      a float, the root-mean square error
    """

    squared_errors = (actual - predicted) ** 2
    mse = np.mean(squared_errors)
    rmse = np.sqrt(mse)
    
    #your code goes here 
    
    return rmse

# %%
#print the error

rmse_value = rmse(y_test, y_predicted)
print(rmse_value)
# Out:
# 36952.056820810445

# %%
# RMSE should be smaller than the spread (std) of the target, otherwise the model is doing very poorly
assert rmse_value < y_test.std()
assert 35000 <= rmse(y_test, y_predicted) <= 37000

# %% [markdown]
# ## 2.3 Checking our model: Residual Plots
#
# Recall from the lectures that one way of diagnosing a model is through a residual plot. Here we plot the actual housing values (`retailvalue`) against the residuals of the model. Ideally, we would see a horizontal line of points at 0 (perfect prediction!). The next best outcome would be a roughly homogeneous cloud of points centered around 0.
#
# However, since our first model is intentionally simple, we may observe systematic patterns in the residuals. In particular, it is common for linear models to underpredict very expensive homes and overpredict cheaper ones. Such patterns indicate that the model is underfitting and failing to capture more complex relationships in the data. You will likely want to address these issues when building your own final model in the open-response section.

# %%
gm1_residuals = y_test - y_predicted

ax = sns.regplot(x=y_test, y=gm1_residuals)
ax.set_xlabel("Retail Value (Test Data)")
ax.set_ylabel("Residuals (Actual Value - Predicted Value)")
plt.show()

# %% [markdown]
# ## 2.4 Regularizing our model
#
# Ok, so let's make our modeling a little more fancy by regularizing the coefficients. This second model will use the Lasso, but you are free to use Ridge or other regularized linear models in your own work.
#
# Before applying regularization, we need to standardize our predictor variables. This is necessary because regularization penalizes large coefficients, and variables measured on different scales would otherwise be treated unfairly. By standardizing each predictor to have mean 0 and standard deviation 1, we ensure that the penalty is applied consistently across features.
#
# #### Question 3 <a name="q3"></a>
#
# Write a function that standardizes the columns of a data frame containing only numeric columns.  Be sure to make use of vectorization.

# %%
def standardize_columns(data):
    '''
    Input:
      data (data frame): contains only numeric columns
    Output:
      data frame, the same data, except each column is standardized 
      to have 0-mean and unit variance
    '''
    #your code goes here [1 line should suffice, don't go nuclear]
    standardized_data = (data - data.mean()) / data.std()
    
    return standardized_data

# %%
# Simple test of the standardization function
test_standardize_df = standardize_columns(
   training_data[["retailvalue", "house-area"]]
)

# Make sure the mean is approximately zero
assert -0.001 < test_standardize_df.mean().sum() < 0.001

# Make sure the standard deviation is approximately one
assert 1.9 < test_standardize_df.std().sum() < 2.1

# %% [markdown]
# We will now define a new processing pipeline for our regularized model. This pipeline is similar to the one used for the simple linear regression model, except that we standardize the predictor variables before fitting the model.

# %%
def process_data_gm2(data):

    data = (
        data
        # -------------------
        # Clean Data
        # -------------------
        .pipe(remove_outliers, "house-area", upper=300)

        # -------------------
        # Feature engineering
        # -------------------
        .pipe(add_house_age)
        .pipe(add_total_outdoor)

        # -------------------
        # Select modeling columns
        # -------------------
        .pipe(select_columns,
              "retailvalue",
              "house-area",
              "bathrooms",
              "total_outdoor",
              "house_age",
              "balcony",
              "energy-eff",
              "monument")
    )

    # IMPORTANT: 
    # Standardize predictors (but not the target)
    # what will happen if we don't standardize?
        # if we don't standarize, the model will be more sensitive to the scale of the predictors, which can cause it to assign more weight to 
        # predictors with larger scales, leading to suboptimal performance and convergence issues during training.

    X = standardize_columns(data.drop(["retailvalue"], axis=1))
    y = data["retailvalue"]

    return X, y

# %% [markdown]
# It may be instructive to see the cross-validation procedure explicitly once.  You should be able to understand what each part of the code is doing below, but we do not expect you to use this code for your own model (use [LassoCV](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LassoCV.html) instead).

# %%
# Process the data
X_train, y_train = process_data_gm2(training_data)
X_test, y_test = process_data_gm2(testing_data)

# Specify the model
guidedmodel2 = lm.Lasso(copy_X=True)

# Specify CV method and grid of regularization values
five_fold_cv = KFold(n_splits=5)
alphas = np.arange(0.001, 10, 0.5)

rmses = np.zeros(len(alphas))

# Grid search over alphas
for i, alpha in enumerate(alphas):
    guidedmodel2.set_params(alpha=alpha)
    model_rmse = 0

    for train_index, test_index in five_fold_cv.split(X_train):
        X_fold_train = X_train.iloc[train_index]
        y_fold_train = y_train.iloc[train_index]
        X_fold_test = X_train.iloc[test_index]
        y_fold_test = y_train.iloc[test_index]

        guidedmodel2.fit(X_fold_train, y_fold_train)
        y_fold_predicted = guidedmodel2.predict(X_fold_test)

        model_rmse += rmse(y_fold_test, y_fold_predicted)

    rmses[i] = model_rmse / 5

optimal_alpha = alphas[rmses == np.min(rmses)][0]

guidedmodel2.set_params(alpha=optimal_alpha)
guidedmodel2.fit(X_train, y_train)

y_predicted = guidedmodel2.predict(X_test)

print(f"The validation RMSE for this model with "
      f"alpha={optimal_alpha} is {rmse(y_test, y_predicted)}.")
# Out:
# The validation RMSE for this model with alpha=5.001 is 37449.68735908106.

# %% [markdown]
# ### 2.4.1 Lasso Path
#
# Let’s examine how RMSE varies across different values of the regularization parameter ($\lambda$ in lecture, `alpha` in `sklearn`). This is known as the regularization path. The dashed red line marks the value of `alpha` that minimizes RMSE.

# %%
plt.plot(alphas, rmses)
plt.axvline(x=optimal_alpha, color="red", linestyle="dashed")

ax = plt.gca()
ax.set_title("Average LASSO RMSE Path")
ax.set_xlabel("Regularization Level (alpha)")
ax.set_ylabel("RMSE")
plt.show()

# %% [markdown]
# Alternative approach: You can also repeat the regularized regression using `LassoCV`, which automatically performs cross-validation over a grid of regularization values.

# %% [markdown]
# ### 2.4.2 Lasso Residual Plot
#
# Looking at the residual plot for our L1 regularized linear model, it's clear the regularization did not solve the problems we saw in the simple model.  It seems you have your work cut out for you!

# %%
gm2_residuals = y_test - y_predicted

ax = sns.regplot(x=y_test, y=gm2_residuals)
ax.set_xlabel("Retail Value (Test Data)")
ax.set_ylabel("Residuals (Actual Value - Predicted Value)")
plt.show()

# %% [markdown]
# #### Question 4
#
# The following questions are supposed to hep you understand the impact of regularization.
#
# 4a) Does adding location features change the chosen `alpha` compared to the non-location model?
#
# 4b) Does the test RMSE improve?
#
# 4c) How many coefficients become exactly zero? Which ones?
#
# 4d) Do you observe any signs of underfitting or overfitting in residual plots after adding location?
#
# Note: Regularization thrives in cases where the dataset is messy (or when there are correlations with the features so it's fine if you don't observe strong effects as we saw in class

# %%
# we set up a new pipeline to include location features
def process_data_gm3(data):
    # -------------------
    # Clean Data
    # -------------------
    data = remove_outliers(data, "house-area", upper=300)

    # -------------------
    # Transform Data
    # -------------------
    data = add_house_age(data)
    data = add_total_outdoor(data)
    
    # here we add new features related to location as well as our proposed features - house to lot ratio and distance to center
    data = add_spatial_neighborhoods(data, k=8)
    data = add_in_rich_neighborhood(data, pricey_locs)
    data = add_location_terms(data)
    data = compute_house_to_lot_ratio(data)
    data = compute_distance_to_center(data)
    

    # -------------------
    # Select modeling columns
    # -------------------
    data = select_columns(
        data,
        "retailvalue",
        "house-area",
        "bathrooms",
        "total_outdoor",
        "house_age",
        "balcony",
        "energy-eff",
        "monument",
        "x2",
        "y2",
        "xy",
        "spatial_neighborhood",
        "in_rich_neighborhood",
        "distance_to_center",
        "house_to_lot_ratio",
    )

    # -------------------
    # Split predictors/target
    # -------------------
    
    X = standardize_columns(data.drop(["retailvalue"], axis=1))
    y = data["retailvalue"]

    return X, y

# %%
X_train_gm3, y_train_gm3 = process_data_gm3(training_data)
X_test_gm3, y_test_gm3 = process_data_gm3(testing_data)

# Specify the model
guidedmodel3 = lm.Lasso(copy_X=True)

# Specify CV method and grid of regularization values
five_fold_cv = KFold(n_splits=5)
alphas = np.arange(0.001, 10, 0.5)

rmses_gm3 = np.zeros(len(alphas))

# Grid search over alphas
for i, alpha in enumerate(alphas):
    guidedmodel3.set_params(alpha=alpha)
    model_rmse = 0

    for train_index, test_index in five_fold_cv.split(X_train_gm3):
        X_fold_train = X_train_gm3.iloc[train_index]
        y_fold_train = y_train_gm3.iloc[train_index]
        X_fold_test = X_train_gm3.iloc[test_index]   
        y_fold_test = y_train_gm3.iloc[test_index]   

        guidedmodel3.fit(X_fold_train, y_fold_train)
        y_fold_predicted = guidedmodel3.predict(X_fold_test)

        model_rmse += rmse(y_fold_test, y_fold_predicted)

    rmses_gm3[i] = model_rmse / 5

optimal_alpha_gm3 = alphas[rmses_gm3 == np.min(rmses_gm3)][0]

guidedmodel3.set_params(alpha=optimal_alpha_gm3)
guidedmodel3.fit(X_train_gm3, y_train_gm3)

y_predicted_gm3 = guidedmodel3.predict(X_test_gm3)


print(f"The validation RMSE for this model with "
        f"alpha={optimal_alpha_gm3} is {rmse(y_test_gm3, y_predicted_gm3):.2f}.")
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.185e+11, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.956e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.169e+11, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.172e+11, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.167e+11, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.065e+11, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.087e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.061e+11, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.060e+11, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.047e+11, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.617e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.320e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.662e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.617e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.436e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.716e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.638e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.827e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.761e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.539e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.929e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.042e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.089e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.008e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.756e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.238e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.503e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.434e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.343e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.069e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.628e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.021e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.850e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.752e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.464e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.088e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.587e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.327e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.226e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.928e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.607e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.195e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.858e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.755e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.452e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.177e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.841e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.436e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.332e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.027e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.792e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.520e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.054e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.952e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.646e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.446e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.228e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.708e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.608e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.304e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.133e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.961e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.394e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.297e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.996e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.850e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.718e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.108e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.014e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.717e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.594e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.495e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.847e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.756e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.465e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.360e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.290e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.608e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.521e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.235e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.147e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# The validation RMSE for this model with alpha=0.001 is 16078.43.
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.101e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.389e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.306e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.026e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.952e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.928e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.188e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.108e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.835e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.774e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.767e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.003e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.927e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.660e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.610e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.619e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.832e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.760e+10, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.499e+10, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.426e+11, tolerance: 6.720e+09
#   model = cd_fast.enet_coordinate_descent(

# %%
# 4a)
print(f"Alpha value for the model without location features: {optimal_alpha:.3f}")
print(f"Alpha value for the model with location features: {optimal_alpha_gm3:.3f}")

# We see that the optimal alpha for the model with location features is much smaller (0.001), than the optimal alpha for the model without location features (5.001). It suggests that the model
# with location features benefits from much less regularization, likely because the additional location features provide valuable information that helps the model fit the data better without overfitting.
# Out:
# Alpha value for the model without location features: 5.001
# Alpha value for the model with location features: 0.001

# %%
# 4b)
print(f"Test RMSE for the model without location features: {rmse(y_test, y_predicted):.2f}")
print(f"Test RMSE for the model with location features : {rmse(y_test_gm3, y_predicted_gm3):.2f}")
print(f"Improvement: {rmse(y_test, y_predicted) - rmse(y_test_gm3, y_predicted_gm3):.2f} euros")
print(f"Relative improvement: {((rmse(y_test, y_predicted) - rmse(y_test_gm3, y_predicted_gm3)) / rmse(y_test, y_predicted)) * 100:.1f}%")

# We observe that the test RMSE for the model with location features is significantly lower than the test RMSE for the model without location features, indicating improvement in model's predictive performance. 
# The absolute improvement in RMSE is 21371.26 euros, which is a meaningful reduction in error given the scale of house prices.
# The relative improvement is approximately 57.1%, which further highlights the value of including location features in the model. 
# This suggests that location is extremly important for determining house prices and that incorporating spatial information can lead to more accurate predictions.
# Out:
# Test RMSE for the model without location features: 37449.69
# Test RMSE for the model with location features : 16078.43
# Improvement: 21371.26 euros
# Relative improvement: 57.1%

# %%
# 4c)
coef_gm3 = pd.Series(guidedmodel3.coef_, index=X_train_gm3.columns)

zero_coefs = coef_gm3[coef_gm3 == 0]
nonzero_coefs = coef_gm3[coef_gm3 != 0]

print(f"Number of coefficients that are exactly zero: {len(zero_coefs)}")
print(f"Number of non-zero coefficients: {len(nonzero_coefs)}")

if len(zero_coefs) > 0:
    print(f"\nCoefficients that are exactly zero:")
    print(zero_coefs)
else :
    print("\nNo coefficients are exactly zero.")

print(f"\nAll coefficients (sorted by absolute value):")
print(coef_gm3.sort_values(key=np.abs, ascending=False))

# We see that no coefficients are set to zero by the LASSO, which suggests that all features are contributing to the model's predictions to some extent.
# The most important features (with the largest absolute coefficients) are house-area, location featurs (x2,y2,xy), total_outdoor as well as our proposed features (house to lot ratio and distance to center),
# which indicates that both the size of the house and the outdoor space along with its location are key determinants of its price.
# Out:
# Number of coefficients that are exactly zero: 0
# Number of non-zero coefficients: 14
#
# No coefficients are exactly zero.
#
# All coefficients (sorted by absolute value):
# house-area             202,053.91
# x2                     -89,731.67
# y2                     -75,144.85
# xy                      56,486.13
# total_outdoor           26,587.49
# house_to_lot_ratio     -16,341.90
# distance_to_center     -13,621.67
# house_age              -12,210.45
# monument                 6,356.91
# in_rich_neighborhood     4,197.27
# bathrooms                3,798.72
# energy-eff              -3,587.05
# spatial_neighborhood     1,989.30
# balcony                    452.61
# dtype: float64

# %%
# 4d) 
gm3_residuals = y_test_gm3 - y_predicted_gm3

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

ax1 = axes[0]
sns.regplot(x=y_test, y=(y_test - y_predicted), ax=ax1)
ax1.axhline(y=0, color='red', linestyle='--', alpha=0.5)
ax1.set_xlabel("Retail Value (Test Data)")
ax1.set_ylabel("Residuals")
ax1.set_title(f"Without Location Features\nRMSE: {rmse(y_test, y_predicted):.0f}")

ax2 = axes[1]
sns.regplot(x=y_test_gm3, y=gm3_residuals, ax=ax2)
ax2.axhline(y=0, color='red', linestyle='--', alpha=0.5)
ax2.set_xlabel("Retail Value (Test Data)")
ax2.set_ylabel("Residuals")
ax2.set_title(f"With Location Features\nRMSE: {rmse(y_test_gm3, y_predicted_gm3):.0f}")

plt.tight_layout()
plt.show()

# %% [markdown]
# By looking at the residual plots, we can observe that the model with location features shows residuals much closer to zero and more randomly scattered around the horizontal line at zero (errors range from around -40000 to 40000, whereas for the other model they are from -100000 to 75000). This indicates that the model with location features is a better fit to the data. Nonetheless, we can notice that the regression fit line of the residuals is consistently below 0 highlighting that the model systematically overestimates the real price. On the other hand, the model without location features shows a positive slope in residuals, which suggests that it tends to overpredict lower-priced houses but shows no pattern with higher-priced houses, indicating some heteroscedasticity in the model. This property seems to disappear in the model which includes location features (the slope is close to zero) - indicating a clear constant bias.
#
# In summary, the model with location based features consistently overestimates the price, but is still significantly more accurate than the one without them. Additionally, with the optimal alpha=0 we observe that the model is not overfitted and all features contribute meaningfully to the prediciton. This observation highlights the importance of using location based features in estimating retail house prices.

# %% [markdown]
# # 3. Let's improve the model, bring out the big guns...
#
# In this part of the clinic, you are asked to go beyond the guided example and design your own predictive model.
#
# You may use any **linear model** discussed in class (perhaps with non-linear polynomial features). Your goal is to **improve prediction performance** on unseen data, measured using **Root Mean Squared Error (RMSE)**.
#
# ---
# ### 📋 What you should do
#
# 1. Construct new features based on existing variables:
#    - Spatial features (latitude, longitude, neighborhoods, clusters)
#    - Polynomial features (e.g., squared terms, interactions)
#    - Aggregated or transformed variables (e.g., total outdoor space, house age)
# 2. Select a set of predictors you believe will improve performance.
# 3. Build a reusable data processing pipeline (similar to the guided model).
# 4. Train a linear or regularized linear model using the training data.
# 5. Evaluate your model using RMSE on the test set.
#
# You are encouraged to experiment and justify your modeling choices.
#
# ---
#
# ### ⚠️ Overfitting Check
#
# - Models that perform extremely well on the training set but poorly on unseen data (we keep a set aside).
# - You should aim for a balance between accuracy and generalization.
#
# Using cross-validation and regularization is strongly recommended.

# %% [markdown]
# ### Grading Scheme
#
# Your model will be assessed based on:
#
# - Predictive performance (RMSE)
# - Soundness of your modeling pipeline
# - Feature engineering choices (including polynomial features where appropriate)
# - Evidence of avoiding overfitting
# - Clear explanation of your approach
#
# There is no single “correct” model — thoughtful experimentation is the goal.

# %% [markdown]
# #### Question 5 <a name="q3"></a>
#
# Just as in the guided model above, you should encapsulate as much of your workflow into functions as possible.  Define `process_data_fm` and `final model` in the cell below. In order to calculate your final model's RMSE, we will run the code in the cell after that.

# %% [markdown]
# **Comment**: some extra EDA to help with creating a better model:

# %%
# Here we want to visually assess if there are any outliers in other area-related fields
fig, axes = plt.subplots(3, 2, figsize=(12, 12),
                         gridspec_kw={"height_ratios": [3, 1, 3]})

for i, var in enumerate(["lot-area", "garden-size"]):
    sns.histplot(training_data[var], kde=True, ax=axes[0, i])
    axes[0, i].set_title(f"Distribution of {var}")
    axes[0, i].set_xlabel("")
    axes[0, i].set_ylabel("Count")

    sns.boxplot(x=training_data[var], ax=axes[1, i])
    axes[1, i].set_xlabel(var)
    axes[1, i].set_xlim(axes[0, i].get_xlim())

    sns.regplot(x=var, y="retailvalue", data=training_data,
                scatter_kws={"s": 12, "alpha": 0.25},
                line_kws={"color": "black"}, ax=axes[2, i])
    axes[2, i].set_xlabel(var)
    axes[2, i].set_ylabel("retailvalue")
    axes[2, i].set_title(f"{var} vs retailvalue")
    axes[2, i].yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.tight_layout()
plt.show()

# %% [markdown]
# Comment: even though the 1.5 IQR rule points out a few outliers they are not clear outliers as they follow a consistent trend hence we will not delete them.

# %% [markdown]
# We can further examine some features that were not analysed before:

# %%
sns.scatterplot(x=training_data["buildyear"], y="retailvalue", data=training_data,
                hue="monument", palette="tab10", s=14, alpha=0.9)
sns.regplot(x=training_data["buildyear"], y="retailvalue", data=training_data,
            scatter=False, line_kws={"color": "black"})
plt.axvline(x=1954, color="red", linestyle="--", label="year 1954")
plt.axvline(x=1990, color="maroon", linestyle="--", label="year 1990")
plt.xlabel("Build Year")
plt.ylabel("Retail Value")
plt.title("House Age vs Retail Value (colored by Energy Efficiency)")
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.legend(title="Energy Eff.")
plt.show()

# %% [markdown]
# As we can see on the graph above there clearly seems to be 3 seperate pricing groups depending on the age of the house. Hence we will hot-encode two new features "old_house" and "new_house".
#
# Additionally in the second and third grouping we can see a that the boundary line between monument and not-monument lies diagonally. Hence we will add a feature "age_times_monument".

# %% [markdown]
# **BUT** unfortunately, after adding "new_house" and "old_house" labels we saw no improvement in the model. After further analyses we found out that the graph above looks like that because of the "house-area" distribution that can be seen below. It follows exactly the same trend, meaning that adding house age features doesn't bring any new information as it is so closely correlated with "house-area" that is already included in the model.
#
# Same thing is true about the second feature we wanted to add.

# %%
training_data = remove_outliers(training_data, "house-area", upper=300)
sns.scatterplot(x=training_data["buildyear"], y="house-area", data=training_data,
                hue="monument", palette="tab10", s=14, alpha=0.9)
sns.regplot(x=training_data["buildyear"], y="house-area", data=training_data,
            scatter=False, line_kws={"color": "black"})
plt.axvline(x=1954, color="red", linestyle="--", label="year 1954")
plt.axvline(x=1990, color="maroon", linestyle="--", label="year 1990")
plt.xlabel("Build Year")
plt.ylabel("House Area")
plt.title("House Age vs Retail Value (colored by Energy Efficiency)")
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.legend(title="Energy Eff.")
plt.show()

# %%
# =========================
# Solution to Open-Response 
# =========================

#import numpy as np
#import pandas as pd

#from sklearn import linear_model as lm
#from sklearn.model_selection import train_test_split
#from sklearn.cluster import KMeans


# -------------------------
# Utility functions (e.g. rmse)
# -------------------------


# -------------------------
# Feature engineering (everything you carry from parts 1 and 2)
# -------------------------

# Same as in when looking for particular rich neighborhoods we can look for the poorest ones too (we will need a bigger number of clusters though)
def find_poor_spatial_neighborhoods(data, n=3, metric="median"):
    # Top-n clusters by median retailvalue
    tmp = (
        data.groupby("spatial_neighborhood")["retailvalue"]
        .agg(metric)
        .sort_values(ascending=True)
    )
    return tmp.head(n).index.tolist()

def add_in_poor_neighborhood(data, poor_clusters):
    data = data.copy()
    data["in_poor_neighborhood"] = data["spatial_neighborhood"].isin(poor_clusters).astype(int)
    return data

# Add polynomial features
def add_polynomial_term(data, term, power):
    """
    Adds simple quadratic terms
    """
    data = data.copy()
    data[f"{term}{power}"] = data[term] ** power
    return data

# Add multiplication terms
def add_multiplication(data, term1, term2):
    """
    Adds simple non-linear terms (multiplication of 2 different terms)
    """
    data = data.copy()
    data[f"{term1}_times_{term2}"] = data[term1] * data[term2] 
    return data 

# Add old_house and new_house hot-encoded features
def add_age_labels(data):
    """
    Adds simple non-linear terms (multiplication of 2 different terms)
    """
    data = data.copy()
    data["old_house"] = (data["buildyear"] <= 1954).astype(int)
    data["new_house"] = (data["buildyear"] >= 1990).astype(int)
    return data 

# Add garden to house ratio to check if the graden is proportionally big to the house (bigger ratio probably means more expensive)
def compute_garden_to_house_ratio(data):
    data = data.copy()
    data["garden_to_house_ratio"] = data["garden-size"] / data["house-area"]
    return data

# Add bathroom to house ratio (big houses with few bathrooms may be cheaper)
def compute_bathroom_to_house_ratio(data):
    data = data.copy()
    data["bathroom_to_house_ratio"] = data["bathrooms"] / data["house-area"]
    return data

# Add squareness - a more square lot is easier to build on and the house may have a better layout
def compute_squareness(data):
    data = data.copy()
    # data["squareness"] = (4 * np.sqrt(data["lot-width"] * data["lot-len"])) / (2 * (data["lot-width"] + data["lot-len"]))
    data["squareness"] = np.minimum(data["lot-width"], data["lot-len"]) / np.maximum(data["lot-width"], data["lot-len"])
    return data

# %%
# -------------------------
# Final processing pipeline (feel free to ingore but is handy to use)
# -------------------------
def process_data_fm(data):#zipcode_categories, kmeans_model, k_clusters=10):
#you might modify this if needed e.g. see below if you use the kmeans exampe or other input
#def process_data_fm(data) #zipcode_categories, kmeans_model, k_clusters=10):
    """
    Final model processing:
      - Clean: outliers
      - Transform: engineered features
      - Encode: zipcode + spatial cluster
      - Standardize: predictors
      - Return: X, y
    """
# code here
    # -------------------
    # Clean Data
    # -------------------
    data = remove_outliers(data, "house-area", upper=300)

    # -------------------
    # Transform Data
    # -------------------
    data = add_house_age(data)

    # here we add new features related to location as well as our proposed features - house to lot ratio and distance to center
    data = add_spatial_neighborhoods(data, k=20)
    pricey_locs = find_rich_spatial_neighborhoods(data, 5)
    data = add_in_rich_neighborhood(data, pricey_locs)
    poor_locs = find_poor_spatial_neighborhoods(data, 5)
    data = add_in_poor_neighborhood(data, poor_locs)
    data = add_location_terms(data)
    data = compute_house_to_lot_ratio(data)
    data = compute_distance_to_center(data)
   

    # These are the new engineered features 
    # Many of these we did not use in the end as seen in the column selection part, but we kept them here for documentation purposes
    
    data = add_polynomial_term(data, "distance_to_center", 2) # the effect of distance may be non-linear so we add quadratic term too
    data = add_polynomial_term(data, "garden-size", 2)
    data = add_polynomial_term(data, "lot-area", 2)
    data = add_polynomial_term(data, "lot-area", 3)
    data= compute_squareness(data)
    data = compute_garden_to_house_ratio(data)
    # From now on we were just playing with different terms to see how it affects the model
    data = add_multiplication(data, "garden-size", "lot-area") # the effect of big lot and garden may be increased when both are big
    data = add_multiplication(data, "house_age", "house-area") # old big mansions may be even more expensive
    data = add_multiplication(data, "balcony", "garden-size")
    data = add_multiplication(data, "distance_to_center", "house_age")
    data = add_multiplication(data, "monument", "distance_to_center")
    data = add_multiplication(data, "distance_to_center", "house-area")
    data = add_polynomial_term(data, "squareness", 2)
    data = add_polynomial_term(data, "squareness", 3)
    data = add_polynomial_term(data, "squareness", 4)
    data = add_multiplication(data, "distance_to_center", "taxvalue")
    data = add_multiplication(data, "taxvalue", "house-area")
    data = add_polynomial_term(data, "taxvalue_times_house-area", 2)
    data = add_polynomial_term(data, "taxvalue_times_house-area", 3)
    data = add_polynomial_term(data, "taxvalue_times_house-area", 4)
    data = add_polynomial_term(data, "taxvalue", 2)
    data = add_polynomial_term(data, "taxvalue", 3)
    data = add_polynomial_term(data, "taxvalue", 4)
    data = add_polynomial_term(data, "taxvalue", 5)
    data = add_multiplication(data, "taxvalue", "lot-area")
    data = add_multiplication(data, "taxvalue", "garden-size")
    data = add_multiplication(data, "taxvalue", "in_rich_neighborhood")
     
    

    
   
    data = compute_bathroom_to_house_ratio(data)
    # -------------------
    # Select modeling columns
    # -------------------


    # Our final model uses all the not commented features (17 total)
    data = select_columns(
        data,
        "retailvalue",
        "house-area",
        "bathrooms",
        "garden-size",
        "lot-area",
        "garden-size2",
        "lot-area2",
        "lot-area3",
        "house_age",
        "balcony",
        "monument",
        "x2",
        "y2",
        "xy",
        "in_rich_neighborhood",
        "in_poor_neighborhood",
        "distance_to_center",
        "distance_to_center2",
        "house_to_lot_ratio",
        "garden_to_house_ratio",
        "house_age_times_house-area",
        "garden-size_times_lot-area",
        "distance_to_center_times_house_age",
        "monument_times_distance_to_center",
        "distance_to_center_times_house-area",
        "squareness",
        "squareness2",
        "squareness3",
        "squareness4",
        # "taxvalue",
        # "distance_to_center_times_taxvalue",
        # "taxvalue_times_house-area",
        # "taxvalue_times_house-area2",
        # "taxvalue_times_house-area3",
        # "taxvalue_times_house-area4",
        # "taxvalue2",
        # "taxvalue3"
        # "energy-eff",
        # "bathroom_to_house_ratio",
    )

    # -------------------
    # Split predictors/target
    # -------------------
    
    # X = standardize_columns(data.drop(["retailvalue"], axis=1))
    X = data.drop("retailvalue", axis=1)
    # y = np.log(data["retailvalue"]) 
    y = (data["retailvalue"]) 
 
    return X, y

# %%
from sklearn.linear_model import LassoCV, RidgeCV
# =========================
# Train/test split (single file)
# =========================
#reloading the data jst in case, same train/test spit
full_data = pd.read_csv("utrechthousing.csv")
training_data, testing_data = train_test_split(full_data, test_size=0.2, random_state=1983)

# pre-process data
X_train, y_train = process_data_fm(training_data)
# y_train_raw = np.exp(y_train) 
X_test, y_test = process_data_fm(testing_data)
# y_test_raw = np.exp(y_test)


# ============================
# Final model (the big winner)
# ============================
final_model = RidgeCV(alphas=np.logspace(-1, 5, 10), cv=5)
# final_model = LassoCV(alphas=np.logspace(-1, 3, 10), cv=5, random_state=1983)

final_model.fit(X_train, y_train)

# y_pred_train = np.exp(final_model.predict(X_train))
# y_pred_test = np.exp(final_model.predict(X_test))
y_pred_train = (final_model.predict(X_train))
y_pred_test = (final_model.predict(X_test))


training_score = rmse(y_train, y_pred_train)  # compare on original scale
test_score = rmse(y_test, y_pred_test)

print("Chosen alpha:", final_model.alpha_)
# print("Chosen l1_ratio:", final_model.l1_ratio_)
print("Training RMSE:", training_score)
print("Test RMSE:", test_score)

# Optional: see which features survived regularization
coef = pd.Series(final_model.coef_, index=X_train.columns).sort_values(key=np.abs, ascending=False)
print("\nTop coefficients by absolute value:")

with pd.option_context('display.float_format', '{:.10f}'.format):
    print(coef.head(30))

#something else?
# Out:
# Chosen alpha: 0.1
# Training RMSE: 5771.993796581009
# Test RMSE: 5675.499388645802
#
# Top coefficients by absolute value:
# distance_to_center                    109551.6682323641
# garden_to_house_ratio                  66332.8986098381
# distance_to_center2                   -49726.9543563950
# squareness2                            30446.2840379945
# squareness4                           -28675.2165648141
# house_to_lot_ratio                     20654.0293671256
# squareness3                            10542.9487758194
# house-area                              4203.1229199443
# lot-area                                3228.9982815085
# in_poor_neighborhood                   -2700.5635558899
# monument_times_distance_to_center       2182.1039975431
# monument                                1838.4688456602
# distance_to_center_times_house_age     -1410.6501447110
# in_rich_neighborhood                   -1250.1429143594
# balcony                                  708.9256261532
# house_age                               -627.1912632670
# garden-size                             -556.4214619457
# distance_to_center_times_house-area     -545.6394281039
# squareness                              -496.0411766262
# bathrooms                               -109.8400585988
# lot-area2                                -10.5226538437
# house_age_times_house-area                 8.3326942394
# garden-size2                               2.3525146837
# garden-size_times_lot-area                -1.4683321079
# x2                                        -0.0888959531
# xy                                         0.0612279293
# y2                                        -0.0302693515
# lot-area3                                  0.0186679291
# dtype: float64
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=5.04853e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=5.20665e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=5.01455e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=5.05749e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=5.09891e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.96469e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=2.04136e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.94681e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.98368e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.97718e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=9.89196e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=1.02318e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=9.81388e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=9.96948e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=9.91392e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=4.12438e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
y_pred_test = final_model.predict(X_test)
residuals = y_test - y_pred_test

sns.regplot(x=y_test, y=residuals, scatter_kws={"s": 12, "alpha": 0.25}, line_kws={"color": "black"})
plt.axhline(y=0, color="red", linestyle="--")
plt.xlabel("Retail Value (Test Data)")
plt.ylabel("Residuals (Actual - Predicted)")
plt.title("Residual Plot")
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.gca().xaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.show()

# %% [markdown]
# **Everything we did with the model:**
# 1. We got rid of old feature "total_outdoor" and used "garden-size" and "lot-area" seperately as using them together was hiding opposite effects that they had on the price prediction.
# 2. We got rid of "spatial-neighborhood" as a feature because it was categorical not numerical - didn't make sense to hot encode with 8 new columns.
# 3. Implemented "in_poor_neighborhoods", and changed the number of spatial clusters to 20
# 4. Looked for outliers in area-related fields.
# 5. Implemented number of enginered features including "house_to_lot_ratio", "garden_to_house_ratio", "bathroom_to_house_ratio", "squareness" and more (we tried other ratios too but deleted most of them)
# 6. Implemented multiple polynomial features and interaction features (two features multiplied by each other)
# 7. Added "taxvalue" to our model.
# 8. Tested Ridge and Lasso regularization techniques (We chose Ridge as the better one as it deals better with colinearity between the features and all our features were meaningful so there was no reason to bring any to 0).
# 9. After noticing that the "optimal" alpha for both techniques was close to zero and the model was still not overfitted we decided to get rid of standarizing the columns and use the raw values instead what boosted the performance significantly.
# 10. After analysing the residual plot we noticed that our algorithm tends to overestimate the prices of the expensive houses. To counteract that we decided to predict the log of the retail price instead and later re-scale it back to the real price. This way the right-skewed distribution of the house prices becomes easier to model as the expensive outliers skew the model less. Unfortunetely it didn't help.
#
#
# **Note on overfitting:**
# We realise that not standarizing the features can weaken the regularization performance of Lasso and Ridge, however, for both of these methods the optimal alpha value found with K-fold method was very close to zero even with coefficients of some features in tens of thousands signaling that no overfitting was present.
#
# Moreover, it dramatically boosted the performance of the algorithm. Intrestingly not standarizing the features didn't affect much the training RMSE at ~5700 but lowered test RMS from ~8800 to ~5600. Hence the RMSE pair for non-standarized data looks even less overfitted as the Train and Test RMSE are closer together.
#
# Additioanlly, with standarizing, there was a systematic error in our predicitons visible on the residual plot - model was consistently overpricing expensive houses. Now, it shows no such trend.
#
#
# **Note on Data Leakage**
# We are not sure how "taxvalue" feature was derived. If it is a widely available number by the public then we think it is okay to use it, otherwise if it is a value that is derived from the retail price then it is a clear data leakage. Without proper background knowledge we can't say for sure. Nonetheless, we decided not to use it (when we used it it was drastically overpowering other features).
#
#
# **Final Note:**
# In the end our model:
# 1. Uses Ridge Regularization with alpha = 0.1
# 2. Does not standarize the features
# 3. Uses 29 features
# 4. Achives train RMSE: 5772 and test RMSE: 5675.

# %%
#training_data = pd.read_csv('ames_train.csv')
#X_train, y_train = process_data_fm(training_data)
#final_model.fit(X_train, y_train)

# %% [markdown]
# ## 4. Assessing Feature Importance via Perturbation Tests
#
# So far, we have evaluated our models using prediction error. However, understanding **which features drive predictions** is equally important — especially when models are used in socially sensitive contexts such as housing valuation.
#
# One intuitive way to assess feature importance is through a **perturbation (permutation) test**. The idea is simple (and we discussed it in class after regularization - so refer to the slides of Chapter/Lecture VI as well):
#
# > If a feature is important, randomly shuffling its values should significantly worsen model performance.
#
# This breaks the relationship between the feature and the target while keeping the rest of the data unchanged.
#
# ---
#
# ### 🔍 Intuition
#
# - Small change in RMSE → feature not very important
# - Large increase in RMSE → feature highly influential
#
# ---
#
# ### 📋 Procedure
#
# 1. Measure the original model RMSE on the test set
# 2. For each feature:
#    - Shuffle its values in the test data
#    - Recompute RMSE
#    - Record the increase in error

# %% [markdown]
# ### Question 6
#
# Implement a perturbation test to estimate the importance of each feature in your model.
#
# Answer the following questions:
#
# - Which features appear most influential?
# - Are any features surprisingly unimportant?
# - (include any other interesting observation you make)
#
# Reflect briefly on what this means for both prediction performance and fairness.

# %%
def perturbation_importance(model, X_test, y_test, metric=rmse):
    """
    Computes feature importance via perturbation tests.
    
    Returns a Series indexed by feature name with RMSE increase values.
    """

    y_pred = (model.predict(X_test))
    original_error = metric(y_test, y_pred)

    rmse_changes= pd.Series(np.nan, index=X_test.columns)

    for feature in X_test.columns:
        X_test_shuffeled = X_test.copy()
        X_test_shuffeled[feature] = X_test_shuffeled[feature].sample(frac=1).values

        shuffeld_y_pred = (model.predict(X_test_shuffeled))
        shuffled_error = metric(y_test, shuffeld_y_pred)

        increase = ((shuffled_error - original_error) / original_error ) * 100
        # increase = shuffled_error - original_error

        rmse_changes[feature] = increase


    return rmse_changes.sort_values(ascending=False)

# %%
# 1) Make sure we use the model that was actually fit
# (final_model was fit on X_train from process_data_fm)
model = final_model

# Align feature columns (protects against column order / missing dummies / extra columns)
#X_test_aligned = X_test.reindex(columns=X_train.columns, fill_value=0)

feature_importance = perturbation_importance(
    model, 
    X_test, 
    y_test
)

feature_importance
# Out:
# house-area                            4,202.19
# x2                                    2,974.98
# lot-area                              2,604.47
# xy                                    2,591.73
# y2                                    2,264.53
# lot-area2                             2,220.10
# lot-area3                               724.42
# house_age_times_house-area              619.36
# distance_to_center_times_house_age      465.98
# house_age                               323.02
# distance_to_center                      290.11
# garden-size                             235.50
# garden_to_house_ratio                   215.78
# distance_to_center_times_house-area     203.81
# house_to_lot_ratio                      121.11
# garden-size_times_lot-area               83.05
# squareness2                              77.04
# distance_to_center2                      66.84
# squareness4                              52.53
# garden-size2                             49.74
# squareness3                              11.98
# monument                                  3.87
# in_poor_neighborhood                      2.94
# monument_times_distance_to_center         1.57
# in_rich_neighborhood                      0.07
# balcony                                   0.04
# bathrooms                                -0.03
# squareness                               -0.10
# dtype: float64

# %%
plt.figure(figsize=(10,6))
feature_importance.plot(kind="bar")
plt.ylabel("Increase in RMSE after perturbation (in percentage)")
plt.title("Feature Importance via Perturbation Test")
plt.show()

# %% [markdown]
# ### ** Analysis and answers to questions goes here**
#
# - Which features appear most influential?
# The most important features is house-area. This makes sense as retail value and house area are heavily correlated as seen in earlier graphs. the features x2, lot-area, xy, y2 and lot-area2 all have a similar level of importance. This implies that besides the house-area the total area of the plot and the location are influencial when prediciting the price. Additionally, x2 and y2 show that there may be a non-linear relationshiop between house location and price. Interestingly, x2 and y2 seem to encode most of the spatial information, while 'in_rich_neighborhood' and 'in_poor_neighborhood' are barely contributing.
#
# - Are any features surprisingly unimportant?
# The features 'balcony' and 'bathrooms' had very low scores in the pertubation test, eventhough intuatively a higher number of bathrooms or balconies would affect the house price. 'squareness' also has a low score on the pertubation test, while 'squareness2' and 'squareness3' have a higher but still marginal importance. This indicates a possible non-linear relationship, meaning when a property is very square or very not-square it affects the price. Removing 'balcony', 'bathrooms' and 'squereness' from the model would reduce redundancy.
#
# - Extra Notes
# Seeing how many features have very low perturbation score we believe many of them could be deleted to decrease the complexity of the model without disturbing the performance.

# %% [markdown]
# ## 5. Assessing Fairness Through Error Analysis Across Locations
#
# High predictive accuracy does not necessarily imply a fair model. In housing valuation, systematic over- or under-estimation in certain areas may disproportionately affect specific communities.
#
# To explore potential fairness issues, we examine whether prediction errors differ across geographic groups, such as zip codes or spatial neighborhoods.
#
# If the model consistently:
#
# - Overestimates values in some areas
# - Underestimates values in others
#
# this may indicate unequal treatment depending on the location your house is in.
#
# ---
#
# ### 📋 Procedure
#
# 1. Compute prediction errors for each house:
#
#    Error = Actual Value − Predicted Value
#
# 2. Group errors by geographic category (e.g., zip code or spatial cluster)
#
# 3. Compare average error and RMSE across groups
#
# ---
#
# ### Question 7
#
# Analyze whether prediction errors differ systematically across locations.
#
# Answer the following:
#
# - Are some neighborhoods consistently overvalued or undervalued?
# - Which areas show the largest prediction errors?
# - What might explain these patterns?
#
# (any other observation you think is worth mentioning)

# %%
# Might be handy to create a results DataFrame
fairness_df = testing_data.copy()

fairness_df["prediction"] = y_pred_test
fairness_df["error"] = fairness_df["retailvalue"] - fairness_df["prediction"]
fairness_df["abs_error"] = np.abs(fairness_df["error"])

# %%
# compute the error per-zipcode (hint: use groupby and agg?)

error = fairness_df.groupby("zipcode")["error"].agg('mean')
abs_error = fairness_df.groupby("zipcode")["abs_error"].agg('mean')

print(abs_error)
print(error)
# Out:
# zipcode
# 3500   2,347.67
# 3525   3,043.87
# 3528   6,216.70
# 3800   4,565.52
# Name: abs_error, dtype: float64
# zipcode
# 3500      312.81
# 3525   -1,155.48
# 3528    3,064.24
# 3800   -1,606.40
# Name: error, dtype: float64

# %%
#plot figure and show any differences?
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

error.plot(kind='bar', ax=axes[0])
axes[0].set_title('Mean Error by Zipcode')
axes[0].set_xlabel('Zipcode')
axes[0].set_ylabel('Mean Error')
axes[0].axhline(0, color='red', linestyle='--', linewidth=1)

abs_error.plot(kind='bar', ax=axes[1], color='coral')
axes[1].set_title('Mean Absolute Error by Zipcode')
axes[1].set_xlabel('Zipcode')
axes[1].set_ylabel('Mean Absolute Error')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(nrows=2)

sns.boxplot(
    x="zipcode",
    y="buildyear",
    data=fairness_df.sort_values("zipcode"),
    ax=axs[0]
)

sns.countplot(
    x="zipcode",
    data=fairness_df.sort_values("zipcode"),
    ax=axs[1]
)



axs[0].axhline(
    y=fairness_df["buildyear"].median(),
    color="green",
    linestyle="dotted"
)

for patch in axs[1].patches:
    x = patch.get_bbox().get_points()[:, 0]
    y = patch.get_bbox().get_points()[1, 1]
    axs[1].annotate(f"{int(y)}", (x.mean(), y), ha="center", va="bottom")


axs[0].set_title("Median Build Year by Zipcode and Sample Count")
axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.subplots_adjust(hspace=0.01)
plt.show()

# %%
fairness_df= add_spatial_neighborhoods(fairness_df) #add neighbourhoods

error_neighbourhood = fairness_df.groupby("spatial_neighborhood")["error"].agg('mean')
abs_error_neighbourhood = fairness_df.groupby("spatial_neighborhood")["abs_error"].agg('mean')

print(abs_error_neighbourhood)
print(error_neighbourhood)
# Out:
# spatial_neighborhood
# 0   3,132.51
# 1   2,434.69
# 2   7,231.59
# 3   2,616.42
# 4   6,553.54
# 5   5,327.27
# 6   3,035.39
# 7   4,154.18
# Name: abs_error, dtype: float64
# spatial_neighborhood
# 0   -1,606.48
# 1      273.78
# 2    3,029.21
# 3      499.30
# 4   -3,614.51
# 5      725.69
# 6     -134.95
# 7     -429.77
# Name: error, dtype: float64

# %%
#plot error for neighbourhoods
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

error_neighbourhood.plot(kind='bar', ax=axes[0])
axes[0].set_title('Mean Error by Neighbourhood')
axes[0].set_xlabel('Neighbourhood')
axes[0].set_ylabel('Mean Error')
axes[0].axhline(0, color='red', linestyle='--', linewidth=1)

abs_error_neighbourhood.plot(kind='bar', ax=axes[1], color='coral')
axes[1].set_title('Mean Absolute Error by Neighbourhood')
axes[1].set_xlabel('Neighbourhood')
axes[1].set_ylabel('Mean Absolute Error')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

sns.boxplot(
    x="spatial_neighborhood",
    y="buildyear",
    data=fairness_df.sort_values("spatial_neighborhood"),
    ax=ax
)

ax.axhline(
    y=fairness_df["buildyear"].median(),
    color="green",
    linestyle="dotted"
)


ax.set_title("Median Build Year by Neighbourhood")
ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.subplots_adjust(hspace=0.01)
plt.show()

# %%
fig, axs = plt.subplots(nrows=2)

sns.boxplot(
    x="spatial_neighborhood",
    y="buildyear",
    data=fairness_df.sort_values("spatial_neighborhood"),
    ax=axs[0]
)

sns.countplot(
    x="spatial_neighborhood",
    data=fairness_df.sort_values("spatial_neighborhood"),
    ax=axs[1]
)



axs[0].axhline(
    y=fairness_df["buildyear"].median(),
    color="green",
    linestyle="dotted"
)

for patch in axs[1].patches:
    x = patch.get_bbox().get_points()[:, 0]
    y = patch.get_bbox().get_points()[1, 1]
    axs[1].annotate(f"{int(y)}", (x.mean(), y), ha="center", va="bottom")


axs[0].set_title("Median Build Year by Neighbourhood and Sample Count")
axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.subplots_adjust(hspace=0.01)
plt.show()

# %%
fig,ax = plt.subplots()

fairness_df["buildyear_bin"] = (fairness_df["buildyear"] // 20) * 20


sns.countplot(
    x="buildyear_bin",
    data=fairness_df.sort_values("buildyear_bin"),
    ax=ax
)

ax.set_title("Bincount per Build Year")
ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.subplots_adjust(hspace=0.01)
plt.show()

# %% [markdown]
# ### ** Analysis and answers to questions goes here**
#
# - Are some neighborhoods consistently overvalued or undervalued?
# When looking at the mean error per zipcode, we can see that zipcodes 3,525 and 3,800 are consistently over valued causing negative error, while the zipcode 3,528 is undervalued on average. Zipcode 3,500 has a mean error of 313 but an absolute error of 2,348 implying that this zipcode is both over- and undervalued on average. However, it is slightly more likely to be undervalued causing a relatively small postive average error of 300.
#
#
# Using the function add_spatial_neighborhoods on the fairness dataframe we split the data into 8 neighbourhoods to get more insight into the fairness of the model. We can see that for most neighbourhoods the model has a relatively low average error, indicating an even split of both under- and overvaluation. Neighbourhoods 0 and 4 are overvalued on average while 2 is undervalued.
#
# - Which areas show the largest prediction errors?
# Zipcode 3528 has by far the largest error at 6217, roughly 2.6x worse than the best performing zipcode 3500 at 2348. 3800 is second worst at 4,566. This indicated a possible bias in the model against these zipcodes. At first, we thought a possible cause for this bias might be that 3528 and 3800 have a smaller sample size. However, in the graph above we can see that these zipcodes actually have the most samples. Interestingly, when looking at the median build year per zipcode, we can observe that these zipcodes have noticably older houses. This would suggest that the model has a bias towards younger houses.
#
# When looking at the neighbourhoods, we see 2 and 4 show the largest prediction errors at 7,232 and 6,554 respectively, followed by 5 at 5,327.
# Neighbourhoods 1 and 3 are the most accurate at 2,435 and 2,616.
# The difference between best and worst is nearly 3x (2,400 vs 7,200), which suggests the model is significantly less accurate across certain areas. In the above graph we can see that neighbourhood 4 does have less samples than the other neighbourhoods, so this could explain the negative bias. However, just like the zipcodes there seems to be a negative correlation between house age and performance, the model performs worse the older a house is.
#
# We can also rule out sample size bias when it comes to age as we can see that there is not a significant difference in the number of old vs young houses.
#
# The model might struggle with older properties as older houses can vary wildly in quality, renovation status, architectural style, making them harder to predict with a linear model. We tried to fix this bias by adding a feature that flag old properties, but we did not see a significant improvement.
#
# The model's less accurate performance on older properties is a fairness concern since older homes are concentrated in certain neighborhoods and are often owned by certain demographics.
